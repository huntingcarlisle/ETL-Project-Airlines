# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pathlib

# %%
flights_1 = pd.read_csv('data/flight_destinations/flights_2020_1.csv')

# %%
flights_1_cleaned = flights_1.drop(columns=['ORIGIN_AIRPORT_ID','PASSENGERS','ORIGIN_WAC','ORIGIN_AIRPORT_SEQ_ID', 'Unnamed: 24','DEST_CITY_MARKET_ID', 'ORIGIN_CITY_MARKET_ID', 'ORIGIN_STATE_FIPS', 'ORIGIN_STATE_NM','DEST_STATE_NM','DEST_AIRPORT_SEQ_ID', 'DEST_AIRPORT_ID','DEST_WAC','TRIP_BREAK','FARE_CLASS', 'DEST_STATE_FIPS'])

# %%
flights_1_cleaned
# Out:
#          YEAR  QUARTER ORIGIN ORIGIN_COUNTRY ORIGIN_STATE_ABR DEST  \
# 0        2020        1    CLT             US               NC  PBI
# 1        2020        1    CLT             US               NC  PBI
# 2        2020        1    DFW             US               TX  DTW
# 3        2020        1    CLT             US               NC  DTW
# 4        2020        1    CLT             US               NC  DTW
# ...       ...      ...    ...            ...              ...  ...
# 8091831  2020        1    ATL             US               GA  SFO
# 8091832  2020        1    ATL             US               GA  PHX
# 8091833  2020        1    ATL             US               GA  SAT
# 8091834  2020        1    ATL             US               GA  IAH
# 8091835  2020        1    ATL             US               GA  IND
#
#         DEST_COUNTRY DEST_STATE_ABR OPERATING_CARRIER
# 0                 US             FL                AA
# 1                 US             FL                AA
# 2                 US             MI                AA
# 3                 US             MI                AA
# 4                 US             MI                AA
# ...              ...            ...               ...
# 8091831           US             CA                DL
# 8091832           US             AZ                DL
# 8091833           US             TX                DL
# 8091834           US             TX                DL
# 8091835           US             IN                DL
#
# [8091836 rows x 9 columns]

# %%
flights_2 = pd.read_csv('data/flight_destinations/flights_2020_2.csv')

# %%
flights_2_cleaned = flights_2.drop(columns=['ORIGIN_AIRPORT_ID','ORIGIN_AIRPORT_SEQ_ID', 'DEST_CITY_MARKET_ID', 'ORIGIN_CITY_MARKET_ID','Unnamed: 13'])

# %%
flights_2_cleaned
# Out:
#          YEAR  QUARTER ORIGIN ORIGIN_COUNTRY ORIGIN_STATE_ABR DEST  \
# 0        2020        2    MSP             US               MN  CLT
# 1        2020        2    OMA             US               NE  CLT
# 2        2020        2    SBN             US               IN  CLT
# 3        2020        2    DAY             US               OH  CLT
# 4        2020        2    MEM             US               TN  CLT
# ...       ...      ...    ...            ...              ...  ...
# 1821581  2020        2    ORD             US               IL  IND
# 1821582  2020        2    ATL             US               GA  LAX
# 1821583  2020        2    IAH             US               TX  DEN
# 1821584  2020        2    DFW             US               TX  ATL
# 1821585  2020        2    MIA             US               FL  STT
#
#         DEST_COUNTRY DEST_STATE_ABR OPERATING_CARRIER
# 0                 US             NC                AA
# 1                 US             NC                YX
# 2                 US             NC                OH
# 3                 US             NC                OH
# 4                 US             NC                YX
# ...              ...            ...               ...
# 1821581           US             IN                MQ
# 1821582           US             CA                DL
# 1821583           US             CO                UA
# 1821584           US             GA                AA
# 1821585           US             VI                AA
#
# [1821586 rows x 9 columns]

# %%
flights_3 = pd.read_csv('data/flight_destinations/flights_2020_3.csv')

# %%
flights_3_cleaned = flights_3.drop(columns='Unnamed: 9')

# %%
flights_3_cleaned
# Out:
#          YEAR  QUARTER ORIGIN ORIGIN_COUNTRY ORIGIN_STATE_ABR DEST  \
# 0        2020        3    CLT             US               NC  BHM
# 1        2020        3    CAE             US               SC  CLT
# 2        2020        3    DFW             US               TX  ORF
# 3        2020        3    CLT             US               NC  CAE
# 4        2020        3    SBP             US               CA  DFW
# ...       ...      ...    ...            ...              ...  ...
# 4295098  2020        3    ORD             US               IL  GSP
# 4295099  2020        3    ORD             US               IL  LGA
# 4295100  2020        3    ORD             US               IL  CHS
# 4295101  2020        3    ORD             US               IL  BTV
# 4295102  2020        3    ORD             US               IL  CAE
#
#         DEST_COUNTRY DEST_STATE_ABR OPERATING_CARRIER
# 0                 US             AL                OH
# 1                 US             NC                PT
# 2                 US             VA                AA
# 3                 US             SC                OH
# 4                 US             TX                MQ
# ...              ...            ...               ...
# 4295098           US             SC                G7
# 4295099           US             NY                UA
# 4295100           US             SC                YX
# 4295101           US             VT                ZW
# 4295102           US             SC                ZW
#
# [4295103 rows x 9 columns]

# %%
flights_4 = pd.read_csv('data/flight_destinations/flights_2020_4.csv')

# %%
flights_4
# Out:
# Empty DataFrame
# Columns: [YEAR, QUARTER, ORIGIN, ORIGIN_COUNTRY, ORIGIN_STATE_ABR, DEST, DEST_COUNTRY, DEST_STATE_ABR, OPERATING_CARRIER, Unnamed: 9]
# Index: []
