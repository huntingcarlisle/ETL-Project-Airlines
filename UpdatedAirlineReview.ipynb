# %%
import pandas as pd
import csv
import pathlib

csvpath = pathlib.Path('AirlineRankingbyProfit.csv')

arline_ranking_data = pd.read_csv(csvpath)

# %%
#ranking of airlines by profit
arline_ranking_data
# Out:
#     Rank               Airline Code Operating Revenue ($000)  \
# 0      1       Delta Air Lines   DL               47,126,335
# 1      2     American Airlines   AA               45,761,125
# 2      3       United Airlines   UA               43,258,541
# 3      4    Southwest Airlines   WN               22,427,753
# 4      5       Alaska Airlines   AS                8,774,664
# 5      6       JetBlue Airways   B6                8,094,008
# 6      7      Spirit Air Lines   NK                3,830,536
# 7      8      SkyWest Airlines   OO                2,910,753
# 8      9     Hawaiian Airlines   HA                2,830,131
# 9     10     Frontier Airlines   F9                2,508,349
# 10    11         Allegiant Air   G4                1,745,985
# 11    12             Envoy Air   MQ                1,385,341
# 12    13      Republic Airways   YX                1,349,429
# 13    14          PSA Airlines   OH                  813,871
# ...

# %%
arline_ranking_data.fillna(0, inplace = True)

# %%
review = arline_ranking_data[['Rank','Airline', 'Code','Operating Revenue ($000)']]

# %%
review
# Out:
#     Rank               Airline Code Operating Revenue ($000)
# 0      1       Delta Air Lines   DL               47,126,335
# 1      2     American Airlines   AA               45,761,125
# 2      3       United Airlines   UA               43,258,541
# 3      4    Southwest Airlines   WN               22,427,753
# 4      5       Alaska Airlines   AS                8,774,664
# 5      6       JetBlue Airways   B6                8,094,008
# 6      7      Spirit Air Lines   NK                3,830,536
# 7      8      SkyWest Airlines   OO                2,910,753
# 8      9     Hawaiian Airlines   HA                2,830,131
# 9     10     Frontier Airlines   F9                2,508,349
# 10    11         Allegiant Air   G4                1,745,985
# 11    12             Envoy Air   MQ                1,385,341
# 12    13      Republic Airways   YX                1,349,429
# 13    14          PSA Airlines   OH                  813,871
# ...

# %%
#top 5 airlines by profit
review.head()
# Out:
#    Rank             Airline Code Operating Revenue ($000)
# 0     1     Delta Air Lines   DL               47,126,335
# 1     2   American Airlines   AA               45,761,125
# 2     3     United Airlines   UA               43,258,541
# 3     4  Southwest Airlines   WN               22,427,753
# 4     5     Alaska Airlines   AS                8,774,664
